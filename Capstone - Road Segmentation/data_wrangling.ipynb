# %%
import image_slicer

import matplotlib.pyplot as plt


from skimage.io import imread, imshow

# %%
image_slicer.slice('labels/label.png', 500)
# Out:
# (<Tile #1 - label_01_01.png>,
#  <Tile #2 - label_01_02.png>,
#  <Tile #3 - label_01_03.png>,
#  <Tile #4 - label_01_04.png>,
#  <Tile #5 - label_01_05.png>,
#  <Tile #6 - label_01_06.png>,
#  <Tile #7 - label_01_07.png>,
#  <Tile #8 - label_01_08.png>,
#  <Tile #9 - label_01_09.png>,
#  <Tile #10 - label_01_10.png>,
#  <Tile #11 - label_01_11.png>,
#  <Tile #12 - label_01_12.png>,
#  <Tile #13 - label_01_13.png>,
#  <Tile #14 - label_01_14.png>,
#  <Tile #15 - label_01_15.png>,
#  <Tile #16 - label_01_16.png>,
#  <Tile #17 - label_01_17.png>,
#  <Tile #18 - label_01_18.png>,
#  <Tile #19 - label_01_19.png>,
#  <Tile #20 - label_01_20.png>,
#  <Tile #21 - label_01_21.png>,
#  <Tile #22 - label_01_22.png>,
#  <Tile #23 - label_01_23.png>,
#  <Tile #24 - label_02_01.png>,
#  <Tile #25 - label_02_02.png>,
#  <Tile #26 - label_02_03.png>,
#  <Tile #27 - label_02_04.png>,
#  <Tile #28 - label_02_05.png>,
#  <Tile #29 - label_02_06.png>,
#  <Tile #30 - label_02_07.png>,
# ...

# %%
image_slicer.slice('images/imagery.png', 500)
# Out:
# (<Tile #1 - imagery_01_01.png>,
#  <Tile #2 - imagery_01_02.png>,
#  <Tile #3 - imagery_01_03.png>,
#  <Tile #4 - imagery_01_04.png>,
#  <Tile #5 - imagery_01_05.png>,
#  <Tile #6 - imagery_01_06.png>,
#  <Tile #7 - imagery_01_07.png>,
#  <Tile #8 - imagery_01_08.png>,
#  <Tile #9 - imagery_01_09.png>,
#  <Tile #10 - imagery_01_10.png>,
#  <Tile #11 - imagery_01_11.png>,
#  <Tile #12 - imagery_01_12.png>,
#  <Tile #13 - imagery_01_13.png>,
#  <Tile #14 - imagery_01_14.png>,
#  <Tile #15 - imagery_01_15.png>,
#  <Tile #16 - imagery_01_16.png>,
#  <Tile #17 - imagery_01_17.png>,
#  <Tile #18 - imagery_01_18.png>,
#  <Tile #19 - imagery_01_19.png>,
#  <Tile #20 - imagery_01_20.png>,
#  <Tile #21 - imagery_01_21.png>,
#  <Tile #22 - imagery_01_22.png>,
#  <Tile #23 - imagery_01_23.png>,
#  <Tile #24 - imagery_02_01.png>,
#  <Tile #25 - imagery_02_02.png>,
#  <Tile #26 - imagery_02_03.png>,
#  <Tile #27 - imagery_02_04.png>,
#  <Tile #28 - imagery_02_05.png>,
# ...

# %%
sample_image = 'imagery_01_02.png'
path_image = 'images/' + sample_image


# read the image using skimage
image = imread(path_image)

plt.imshow(image)

# %%
sample_mask = 'label_01_02.png'
path_mask = 'labels/' + sample_mask


# read the image using skimage
mask = imread(path_mask)

plt.imshow(mask)
